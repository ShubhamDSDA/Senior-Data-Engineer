# %%
#build for series and dataframe
#panel data - padas
#build on numpy

# %%
# !pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
#series - only one column and multiple rows

# %%
data = [10,20,30,40,50,60]  # list

# %%
data
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
pd.Series(data)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64

# %%
pd.Series(data , index =["a", "b", "c", "d", "e", "f"])
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# dtype: int64

# %%
#dict

# %%
data = {"a":10, "b":20, "c":30}

# %%
pd.Series(data)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(data, name= "Column1")
# Out:
# a    10
# b    20
# c    30
# Name: Column1, dtype: int64

# %%
data1 = { "name": ["rahul", "shubham", "sneha"],
         "Age": [28,27,30],
          "city": ["wardha", "pune", "yavatmal"]}

# %%
data1
# Out:
# {'name': ['rahul', 'shubham', 'sneha'],
#  'Age': [28, 27, 30],
#  'city': ['wardha', 'pune', 'yavatmal']}

# %%
# series

# %%
pd.Series(data1, name="column1")
# Out:
# name     [rahul, shubham, sneha]
# Age                 [28, 27, 30]
# city    [wardha, pune, yavatmal]
# Name: column1, dtype: object

# %%
#dataframe

# %%
pd.DataFrame(data1)
# Out:
#       name  Age      city
# 0    rahul   28    wardha
# 1  shubham   27      pune
# 2    sneha   30  yavatmal

# %%
pd.DataFrame(data1, index=["row1", "row2", "row3"])
# Out:
#          name  Age      city
# row1    rahul   28    wardha
# row2  shubham   27      pune
# row3    sneha   30  yavatmal

# %%
df = pd.DataFrame(data1, index=["row1", "row2", "row3"])

# %%
df
# Out:
#          name  Age      city
# row1    rahul   28    wardha
# row2  shubham   27      pune
# row3    sneha   30  yavatmal

# %%
# attribute

# %%
df.index
# Out:
# Index(['row1', 'row2', 'row3'], dtype='object')

# %%
df.columns
# Out:
# Index(['name', 'Age', 'city'], dtype='object')

# %%
df.dtypes
# Out:
# name    object
# Age      int64
# city    object
# dtype: object

# %%
df.shape
# Out:
# (3, 3)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 9

# %%
df.values
# Out:
# array([['rahul', 28, 'wardha'],
#        ['shubham', 27, 'pune'],
#        ['sneha', 30, 'yavatmal']], dtype=object)

# %%
# methods

# %%
df.head()   #always shows first 5 rows
# Out:
#          name  Age      city
# row1    rahul   28    wardha
# row2  shubham   27      pune
# row3    sneha   30  yavatmal

# %%
df.head(2)
# Out:
#          name  Age    city
# row1    rahul   28  wardha
# row2  shubham   27    pune

# %%
df.tail() #last 5 rows
# Out:
#          name  Age      city
# row1    rahul   28    wardha
# row2  shubham   27      pune
# row3    sneha   30  yavatmal

# %%
df.tail(1)
# Out:
#        name  Age      city
# row3  sneha   30  yavatmal

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, row1 to row3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   city    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   28.333333
# std     1.527525
# min    27.000000
# 25%    27.500000
# 50%    28.000000
# 75%    29.000000
# max    30.000000

# %%
df.describe(include="all")
# Out:
#          name        Age    city
# count       3   3.000000       3
# unique      3        NaN       3
# top     rahul        NaN  wardha
# freq        1        NaN       1
# mean      NaN  28.333333     NaN
# std       NaN   1.527525     NaN
# min       NaN  27.000000     NaN
# 25%       NaN  27.500000     NaN
# 50%       NaN  28.000000     NaN
# 75%       NaN  29.000000     NaN
# max       NaN  30.000000     NaN

# %%
df.sample(2)
# Out:
#        name  Age      city
# row1  rahul   28    wardha
# row3  sneha   30  yavatmal

# %%
#pandas read function

# %%
#excel -worksheet
#csv - comma sepreted values
#jeson

# %%
#pd.read

# %%
df = pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df.sample(2)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2135    -117.91     33.65                17.0       1328.0           377.0
# 1617    -117.12     32.57                35.0       1450.0           256.0
#
#       population  households  median_income  median_house_value
# 2135       762.0       344.0         2.2222            276800.0
# 1617       930.0       286.0         2.6715            133300.0

# %%
df["total_rooms"]
# Out:
# 0       3885.0
# 1       1510.0
# 2       3589.0
# 3         67.0
# 4       1241.0
#          ...
# 2995    1450.0
# 2996    5257.0
# 2997     956.0
# 2998      96.0
# 2999    1765.0
# Name: total_rooms, Length: 3000, dtype: float64

# %%
df[["total_rooms", "total_bedrooms"]]
# Out:
#       total_rooms  total_bedrooms
# 0          3885.0           661.0
# 1          1510.0           310.0
# 2          3589.0           507.0
# 3            67.0            15.0
# 4          1241.0           244.0
# ...           ...             ...
# 2995       1450.0           642.0
# 2996       5257.0          1082.0
# 2997        956.0           201.0
# 2998         96.0            14.0
# 2999       1765.0           263.0
#
# [3000 rows x 2 columns]

# %%
df.iloc[2997]   #index location
# Out:
# longitude              -119.7000
# latitude                 36.3000
# housing_median_age       10.0000
# total_rooms             956.0000
# total_bedrooms          201.0000
# population              693.0000
# households              220.0000
# median_income             2.2895
# median_house_value    62000.0000
# Name: 2997, dtype: float64

# %%
# Out:
# longitude              -119.5600
# latitude                 36.5100
# housing_median_age       37.0000
# total_rooms            1018.0000
# total_bedrooms          213.0000
# population              663.0000
# households              204.0000
# median_income             1.6635
# median_house_value    67000.0000
# Name: 5, dtype: float64

# %%
df1 = pd.DataFrame(data1, index=["row1", "row2", "row3"])

# %%
df1
# Out:
#          name  Age      city
# row1    rahul   28    wardha
# row2  shubham   27      pune
# row3    sneha   30  yavatmal

# %%
df1.iloc[1]  #number
# Out:
# name    shubham
# Age          27
# city       pune
# Name: row2, dtype: object

# %%
df1.loc['row1']  #name
# Out:
# name     rahul
# Age         28
# city    wardha
# Name: row1, dtype: object
